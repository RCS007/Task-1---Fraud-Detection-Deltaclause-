# %% [markdown]
# ***Imporing*** ***Libraries***

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25838 entries, 0 to 25837
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    25838 non-null  int64
#  1   V1      25838 non-null  float64
#  2   V2      25838 non-null  float64
#  3   V3      25837 non-null  float64
#  4   V4      25837 non-null  float64
#  5   V5      25837 non-null  float64
#  6   V6      25837 non-null  float64
#  7   V7      25837 non-null  float64
#  8   V8      25837 non-null  float64
#  9   V9      25837 non-null  float64
#  10  V10     25837 non-null  float64
#  11  V11     25837 non-null  float64
#  12  V12     25837 non-null  float64
#  13  V13     25837 non-null  float64
#  14  V14     25837 non-null  float64
#  15  V15     25837 non-null  float64
#  16  V16     25837 non-null  float64
#  17  V17     25837 non-null  float64
#  18  V18     25837 non-null  float64
#  19  V19     25837 non-null  float64
#  20  V20     25837 non-null  float64
#  21  V21     25837 non-null  float64
#  22  V22     25837 non-null  float64
#  23  V23     25837 non-null  float64
#  24  V24     25837 non-null  float64
#  25  V25     25837 non-null  float64
#  26  V26     25837 non-null  float64
#  27  V27     25837 non-null  float64
#  28  V28     25837 non-null  float64
#  29  Amount  25837 non-null  float64
#  30  Class   25837 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 6.1 MB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    25749
# 1.0       88
# Name: Class, dtype: int64

# %% [markdown]
# **This** **Dataset** **is** **highly** **unblanced**

# %% [markdown]
# 0 --> *Normal* *Transaction*
#
# 1 --> *fraudulent* *transaction*

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (25749, 31)
# (88, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    25749.000000
# mean        75.726227
# std        219.488324
# min          0.000000
# 25%          6.200000
# 50%         18.960000
# 75%         67.500000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      88.000000
# mean      100.010000
# std       265.845031
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    19380.491087 -0.197045  0.145743   0.767372  0.208854 -0.174420
# 1.0    17935.875000 -8.613716  6.376169 -12.221731  6.231847 -6.027247
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.088572 -0.100712  0.011278  0.453641  ...  0.039986 -0.039570
# 1.0   -2.487080 -8.308784  4.351326 -2.987199  ...  0.714069  0.539387
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.131409 -0.038716  0.012076  0.128670  0.022883  0.010424  0.003824
# 1.0   -0.381823 -0.350615 -0.252970  0.346695  0.179760  0.856336  0.100578
#
#            Amount
# Class
# 0.0     75.726227
# 1.0    100.010000
#
# [2 rows x 30 columns]

# %% [markdown]
# **Under**-**Sampling**

# %% [markdown]
# *Build* *a* *sample* *dataset* *containing* *similar* *distribution* *of* *normal* *transactions* *and* *Fraudulent* *Transactions*

# %% [markdown]
# *Number* *of* *Fraudulent* *Transactions* --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 7728   10753 -1.343270  1.118134  1.353682  0.309346  2.432499  4.403758
# 3580    3061 -0.662682  0.659937 -0.638631 -3.281716  2.658786  2.742238
# 1355    1054  1.164216  0.256008  1.085755  2.312421 -0.075168  1.163494
# 4181    3749  1.335998 -0.791827 -0.953032 -1.588856  1.424908  3.286921
# 15022  26355  1.211344  0.297232  0.275178  0.645113 -0.193085 -0.604594
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 7728  -0.363086  0.997213  0.779521  ...  0.005542 -0.051139 -0.327070
# 3580   0.573038  0.530609  0.956976  ... -0.007184  0.231575 -0.285860
# 1355  -0.606673  0.320808 -0.239963  ... -0.097934 -0.103847 -0.125748
# 4181  -1.125491  0.701575  0.356124  ... -0.257613 -0.916113  0.051428
# 15022  0.004596 -0.060792  0.041092  ... -0.260383 -0.722741  0.159044
#
#             V24       V25       V26       V27       V28  Amount  Class
# 7728   0.934150  0.538027 -0.091947 -0.504313  0.040985    1.00    0.0
# 3580   1.004643  0.280460 -0.831541  0.215629  0.032915    1.00    0.0
# 1355  -0.818073  0.460946  0.008041  0.044874  0.016193    1.00    0.0
# 4181   0.921757  0.344609 -0.511989 -0.026322  0.021330   75.79    0.0
# 15022  0.031722  0.140178  0.124298 -0.007297  0.027392    2.69    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 18773  29753  0.269614  3.549755 -5.810353  5.809370  1.538808 -2.269219
# 18809  29785  0.923764  0.344048 -2.880004  1.721680 -3.019565 -0.639736
# 20198  30852 -2.830984  0.885657  1.199930  2.861292  0.321669  0.289966
# 23308  32686  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
# 23422  32745 -2.179135  0.020218 -2.182733  2.572046 -3.663733  0.081568
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 18773 -0.824203  0.351070 -3.759059  ...  0.371121 -0.322290 -0.549856
# 18809 -3.801325  1.299096  0.864065  ...  0.899931  1.481271  0.725266
# 20198  1.767760 -2.451050  0.069736  ...  0.546589  0.334971  0.172106
# 23308 -2.202318  0.555088 -2.033892  ...  0.262202 -0.633528  0.092891
# 23422  0.268049  0.660437 -2.374027  ...  1.026421  0.299614  1.656800
#
#             V24       V25       V26       V27       V28  Amount  Class
# 18773 -0.520629  1.378210  0.564714  0.553255  0.402400    0.68    1.0
# 18809  0.176960 -1.815638 -0.536517  0.489035 -0.049729   30.30    1.0
# 20198  0.623590 -0.527114 -0.079215 -2.532445  0.311177  104.81    1.0
# 23308  0.187613  0.368708 -0.132474  0.576561  0.309843    0.00    1.0
# 23422  0.328433  0.106457  0.691775  0.196779  0.241085  717.15    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0     88
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    18909.101626 -0.179886  0.148000   0.781469  0.150890 -0.144198
# 1.0    17935.875000 -8.613716  6.376169 -12.221731  6.231847 -6.027247
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.238151 -0.081641  0.157495  0.438797  ...  0.058224 -0.067227
# 1.0   -2.487080 -8.308784  4.351326 -2.987199  ...  0.714069  0.539387
#
#             V22       V23       V24       V25      V26       V27       V28  \
# Class
# 0.0   -0.122508 -0.004951  0.047942  0.108430  0.03365  0.016046  0.002667
# 1.0   -0.381823 -0.350615 -0.252970  0.346695  0.17976  0.856336  0.100578
#
#            Amount
# Class
# 0.0     74.600549
# 1.0    100.010000
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 7728   10753 -1.343270  1.118134  1.353682  0.309346  2.432499  4.403758
# 3580    3061 -0.662682  0.659937 -0.638631 -3.281716  2.658786  2.742238
# 1355    1054  1.164216  0.256008  1.085755  2.312421 -0.075168  1.163494
# 4181    3749  1.335998 -0.791827 -0.953032 -1.588856  1.424908  3.286921
# 15022  26355  1.211344  0.297232  0.275178  0.645113 -0.193085 -0.604594
# ...      ...       ...       ...       ...       ...       ...       ...
# 18773  29753  0.269614  3.549755 -5.810353  5.809370  1.538808 -2.269219
# 18809  29785  0.923764  0.344048 -2.880004  1.721680 -3.019565 -0.639736
# 20198  30852 -2.830984  0.885657  1.199930  2.861292  0.321669  0.289966
# 23308  32686  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
# 23422  32745 -2.179135  0.020218 -2.182733  2.572046 -3.663733  0.081568
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 7728  -0.363086  0.997213  0.779521  ... -0.195989  0.005542 -0.051139
# 3580   0.573038  0.530609  0.956976  ...  0.263507 -0.007184  0.231575
# 1355  -0.606673  0.320808 -0.239963  ... -0.041191 -0.097934 -0.103847
# 4181  -1.125491  0.701575  0.356124  ...  0.290945 -0.257613 -0.916113
# 15022  0.004596 -0.060792  0.041092  ... -0.115921 -0.260383 -0.722741
# ...         ...       ...       ...  ...       ...       ...       ...
# 18773 -0.824203  0.351070 -3.759059  ...  0.310525  0.371121 -0.322290
# 18809 -3.801325  1.299096  0.864065  ...  0.170872  0.899931  1.481271
# 20198  1.767760 -2.451050  0.069736  ... -1.016923  0.546589  0.334971
# 23308 -2.202318  0.555088 -2.033892  ...  0.265250  0.262202 -0.633528
# 23422  0.268049  0.660437 -2.374027  ...  1.957960  1.026421  0.299614
#
#             V23       V24       V25       V26       V27       V28  Amount
# 7728  -0.327070  0.934150  0.538027 -0.091947 -0.504313  0.040985    1.00
# 3580  -0.285860  1.004643  0.280460 -0.831541  0.215629  0.032915    1.00
# 1355  -0.125748 -0.818073  0.460946  0.008041  0.044874  0.016193    1.00
# 4181   0.051428  0.921757  0.344609 -0.511989 -0.026322  0.021330   75.79
# 15022  0.159044  0.031722  0.140178  0.124298 -0.007297  0.027392    2.69
# ...         ...       ...       ...       ...       ...       ...     ...
# 18773 -0.549856 -0.520629  1.378210  0.564714  0.553255  0.402400    0.68
# 18809  0.725266  0.176960 -1.815638 -0.536517  0.489035 -0.049729   30.30
# 20198  0.172106  0.623590 -0.527114 -0.079215 -2.532445  0.311177  104.81
# 23308  0.092891  0.187613  0.368708 -0.132474  0.576561  0.309843    0.00
# 23422  1.656800  0.328433  0.106457  0.691775  0.196779  0.241085  717.15
#
# [580 rows x 30 columns]

# %%
print(Y)
# Out:
# 7728     0.0
# 3580     0.0
# 1355     0.0
# 4181     0.0
# 15022    0.0
#         ...
# 18773    1.0
# 18809    1.0
# 20198    1.0
# 23308    1.0
# 23422    1.0
# Name: Class, Length: 580, dtype: float64

# %% [markdown]
# **Split** **the** **data** **into** **Training** **data** **bold text** **&** **Testing** **Data**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (580, 30) (464, 30) (116, 30)

# %% [markdown]
# ***Model*** ***Training***

# %% [markdown]
# **Logistic** **Regression**

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# *Model* *Evaluation*

# %% [markdown]
# **Accuracy** **Score**

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9849137931034483

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9655172413793104
